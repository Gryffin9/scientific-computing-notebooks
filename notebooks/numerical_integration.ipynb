# %% [markdown]
# # Numerical Integration Demo
#
# This notebook compares trapezoid and Simpson rules on an integral with a known analytic value.

# %%
import math
from scicomp_demos import convergence_table

rows = convergence_table(math.sin, 0.0, math.pi, 2.0, [10, 20, 40, 80])
rows
