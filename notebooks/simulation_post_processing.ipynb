# %% [markdown]
# # Simulation Post-Processing Demo
#
# This notebook generates deterministic synthetic oscillator data and extracts summary metrics.

# %%
from scicomp_demos import damped_oscillator_samples, summarize_samples

samples = damped_oscillator_samples()
summarize_samples(samples)
